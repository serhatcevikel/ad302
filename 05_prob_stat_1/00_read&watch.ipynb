# %% [markdown]
# <font size="6"><b>RESOURCES FOR PROBABILITY REFRESHER 1</b></font>

# %% [markdown]
# # Watchlist

# %% [markdown]
# [![linear_algebra watch list](https://img.youtube.com/vi/zF34fXRivbM/0.jpg)](https://www.youtube.com/playlist?list=PLg3eScSbYgxnbA10RR-FTpH_aZ6BGWVda)
