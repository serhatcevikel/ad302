# %% [markdown]
# <font size="6"><b>RESOURCES FOR LINEAR ALGEBRA IN A NUTSHELL</b></font>

# %% [markdown]
# # Watchlist

# %% [markdown]
# [![linear_algebra watch list](https://img.youtube.com/vi/QL4_4GAWvPs/0.jpg)](https://www.youtube.com/playlist?list=PLg3eScSbYgxlxhAVnLsPvhc_Fuu_PMBQ7)

# %% [markdown]
# # Interactive Tools

# %% [markdown]
# - Linear Transformation Visualizer - Inspired by 3Blue1Brown
#
#   https://shad.io/MatVis/
#
# - Linear Transformations | Visualize It
#
#   https://visualize-it.github.io/linear_transformations/simulation.html

# %% [markdown]
# # Online Courses

# %% [markdown]
# - Linear Algebra for Data Science in R (especially 1st and 2nd chapters)
#
#   https://app.datacamp.com/learn/courses/linear-algebra-for-data-science-in-r

# %% [markdown]
# <font size="6"><b>RESOURCES FOR DATA VISUALIZATION, RMARKDOWN AND SHINY</b></font>

# %% [markdown]
# # Data Visualization Resources

# %% [markdown]
# ## Watchlist

# %% [markdown]
# [![visualization watch list](https://img.youtube.com/vi/hr2X7rmkprM/0.jpg)](https://www.youtube.com/playlist?list=PLg3eScSbYgxkOvXovC9W6CzoepVBHkrCZ)

# %% [markdown]
# ## Reading material

# %% [markdown]
# - ggplot2 and the grammer of graphics
#
# https://r-unimelb.gitbook.io/rbook/putting-the-r-in-art/ggplot2-and-the-grammar-of-graphics

# %% [markdown]
# - A quick introduction to ggplot2
#
# https://towardsdatascience.com/a-quick-introduction-to-ggplot2-d406f83bb9c9

# %% [markdown]
# # Rmarkdown Resources

# %% [markdown]
# ## Watchlist

# %% [markdown]
# [![rmarkdown watch list](https://img.youtube.com/vi/DNS7i2m4sB0/0.jpg)](https://www.youtube.com/playlist?list=PLg3eScSbYgxnK2W4DmQDBHCDKihX8tzTv)

# %% [markdown]
# ## Reading material

# %% [markdown]
# - RMarkdown Basics
#
# https://bookdown.org/yihui/rmarkdown/basics.html

# %% [markdown]
# # Shiny Resources

# %% [markdown]
# ## Watchlist

# %% [markdown]
# [![shiny watch list](https://img.youtube.com/vi/HVa42mJYppE/0.jpg)](https://www.youtube.com/playlist?list=PLg3eScSbYgxlNMz9YtMkJQB1tU9Ko9S8T)

# %% [markdown]
# ## Reading material

# %% [markdown]
# - Welcome to Shiny
#
# https://shiny.posit.co/r/getstarted/shiny-basics/lesson1/index.html

# %% [markdown]
# - Your first Shiny app
#
# https://mastering-shiny.org/basic-app.html
